# %% [markdown]
# Generate

# %% [markdown]
# Test : Reconstruction of a face from a single image

# %%
! py -u ./optimizer.py --input input/test/s1.png --output output/test/s1
# Out:
# loading optim config from:  ./optimConfig.ini
# Loading Basel Face Model 2017 from ./baselMorphableModel/morphableModel-2017.pickle...
# loading mesh normals...
# loading uv parametrization...
# loading landmarks association file...
# creating sampler...
# .
# loading image from path: input/test/s1.png
# detecting landmarks using: fan
# 2023-08-22 14:51:12 WARN  main  [BitmapTexture] BitmapTexture: texture named "diffuseMap_0.png" contains pixels that exceed the [0, 1] range!
# 2023-08-22 14:51:12 WARN  main  [BitmapTexture] BitmapTexture: texture named "diffuseMap_0.png" contains pixels that exceed the [0, 1] range!
# 2023-08-22 14:51:12 WARN  main  [BitmapTexture] BitmapTexture: texture named "diffuseMap_0.png" contains pixels that exceed the [0, 1] range!
# 2023-08-22 14:51:12 WARN  main  [BitmapTexture] BitmapTexture: texture named "diffuseMap_0.png" contains pixels that exceed the [0, 1] range!
# ...

# %% [markdown]
# Test : Reconstruction of a faces from a folder

# %%
! py ./optimizer.py --input input/test/ --output output/test/all_images
